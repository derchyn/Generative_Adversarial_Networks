# %% [markdown]
# # Cycle-Consistent Adversarial Networks

# %% [markdown]
# ### Theory:
#
# The generator process:
#
# <img src="assets/generator.png" style="width: 600px;"/>
#
# The discriminator process:
#
# <img src="assets/discriminator.png" style="width: 600px;"/>
#
#
# ### Result Improvement by
# * Data augmentation
# * Resize convolution[4]
# * Instance normalization[5]
#
#
# #### data augmentation:
# <img src="assets/data_augmentation.png" style="width: 600px;"/>
#
# #### Instance normalization and comparision by original paper https://arxiv.org/abs/1607.08022:
# <img src="assets/instance_norm.png" style="width: 600px;"/>
#
#
# #### Resize convolution (Remove Checkerboard Artifacts):
#
# <img src="assets/compare1.png" style="width: 600px;"/>
#
# <img src="assets/compare2.png" style="width: 600px;"/>

# %%
import os
import pprint
import numpy as np
import tensorflow as tf
import tensorlayer as tl
import argparse
from collections import namedtuple
from tensorlayer.layers import *
from tensorlayer.prepro import *
from random import shuffle
from model_deconv import *

# %%
epoch =  1   #200  #Epoch to train [100]
learning_rate = 0.0002  #Learning rate of for adam [0.0002]
beta1 = 0.5  #Momentum term of adam [0.5]
weight_decay = 1e-5  #Weight decay for l2 loss
pool_size = 50  #size of image buffer that stores previously generated images, default: 50
train_size = np.inf  #The size of train images [np.inf]
batch_size = 1  #The number of batch images [1] if we use InstanceNormLayer !
image_size = 256  #The size of image to use (will be center cropped) [256]
gf_dim = 32  #Size of generator filters in first layer
df_dim = 64  #Size of discriminator filters in first layer
class_embedding_size = 5  #Size of class embedding
output_size = 256  #The size of the output images to produce [64]
sample_size = 64  #The number of sample images [64]
c_dim = 3  #Dimension of image color. [3]
sample_step = 500  #The interval of generating sample. [500]
save_step = 200  #The interval of saveing checkpoints. [200]

dataset_dir = "sunflower2daisy"  #The name of dataset [horse2zebra, apple2orange, sunflower2daisy and etc]
checkpoint_dir = "checkpoint"  #Directory name to save the checkpoints [checkpoint]
sample_dir = "samples"  #Directory name to save the image samples [samples]
direction = "forward"  #The direction of generator [forward, backward]
test_dir = "./test"  #The direction of test
is_train = True   #True for training, False for testing [False]
is_crop = False  #True for training, False for testing [False]

# %%
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# %%
sess = tf.Session()

# %% [markdown]
# ##  Train CycleGAN

# %%
ni = int(np.sqrt(batch_size))
h, w = 256, 256
lamda = 10
# num_fake = 0

# %%
## data augmentation
def prepro(x):
    x = tl.prepro.flip_axis(x, axis=1, is_random=True)
    x = tl.prepro.rotation(x, rg=16, is_random=True, fill_mode='nearest')
    x = tl.prepro.imresize(x, size=[int(h * 1.2), int(w * 1.2)], interp='bicubic', mode=None)
    x = tl.prepro.crop(x, wrg=h, hrg=w, is_random=True)
    x = x / (255. / 2.)
    x = x - 1.
    return x

# %%
## data rescale 
def rescale(x):
    x = x / (255. / 2.)
    x = x - 1.
    return x

# %%
real_A = tf.placeholder(tf.float32, [None, image_size, image_size, c_dim], name='real_A')
real_B = tf.placeholder(tf.float32, [None, image_size, image_size, c_dim], name='real_B')
fake_A_pool = tf.placeholder(tf.float32, [batch_size, image_size, image_size, c_dim], name='fake_A')
fake_B_pool = tf.placeholder(tf.float32, [batch_size, image_size, image_size, c_dim], name='fake_B')

# %%
gen_B, gen_B_out = cyclegan_generator_resnet(real_A, 9, is_train=True, reuse=False, name='gen_A2B')
gen_A, gen_A_out = cyclegan_generator_resnet(real_B, 9, is_train=True, reuse=False, name='gen_B2A')
cyc_B, cyc_B_out = cyclegan_generator_resnet(gen_A_out, 9, is_train=True, reuse=True, name='gen_A2B')
cyc_A, cyc_A_out = cyclegan_generator_resnet(gen_B_out, 9, is_train=True, reuse=True, name='gen_B2A')

d_real_A, d_real_A_logits = cyclegan_discriminator_patch(real_A, is_train=True, reuse=False, name='dis_A')  
# dx
d_real_B, d_real_B_logits = cyclegan_discriminator_patch(real_B, is_train=True, reuse=False, name='dis_B')  
# dy
d_fake_A, d_fake_A_logits = cyclegan_discriminator_patch(gen_A_out, is_train=True, reuse=True, name='dis_A')  
# d_fy
d_fake_B, d_fake_B_logits = cyclegan_discriminator_patch(gen_B_out, is_train=True, reuse=True, name='dis_B')  
# d_gx

d_A_pool, d_A_pool_logits = cyclegan_discriminator_patch(fake_A_pool, is_train=True, reuse=True, name='dis_A')  
# d_fakex
d_B_pool, d_B_pool_logits = cyclegan_discriminator_patch(fake_B_pool, is_train=True, reuse=True, name='dis_B')  
# d_fakey
# Out:
#   [TL] InputLayer  gen_A2B/in: (?, 256, 256, 3)
#   [TL] Conv2dLayer gen_A2B/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/0: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/1: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/2: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/3: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/4: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/5: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/6: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/7: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/8: size:(?, 64, 64, 128) fn:add
#   [TL] DeConv2dLayer gen_A2B/u64: shape:[3, 3, 64, 128] out_shape:[<tf.Tensor 'gen_A2B/strided_slice:0' shape=() dtype=int32>, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_A2B/u32: shape:[3, 3, 32, 64] out_shape:[<tf.Tensor 'gen_A2B/strided_slice_1:0' shape=() dtype=int32>, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh
#   [TL] InputLayer  gen_B2A/in: (?, 256, 256, 3)
#   [TL] Conv2dLayer gen_B2A/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/0: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/1: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/2: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/3: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/4: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/5: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/6: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/7: size:(?, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/8: size:(?, 64, 64, 128) fn:add
#   [TL] DeConv2dLayer gen_B2A/u64: shape:[3, 3, 64, 128] out_shape:[<tf.Tensor 'gen_B2A/strided_slice:0' shape=() dtype=int32>, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_B2A/u32: shape:[3, 3, 32, 64] out_shape:[<tf.Tensor 'gen_B2A/strided_slice_1:0' shape=() dtype=int32>, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh
#   [TL] InputLayer  gen_A2B/in: (?, ?, ?, 3)
#   [TL] Conv2dLayer gen_A2B/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/0: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/1: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/2: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/3: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/4: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/5: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/6: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/7: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_A2B/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B/b_residual_add/8: size:(?, ?, ?, 128) fn:add
#   [TL] DeConv2dLayer gen_A2B/u64: shape:[3, 3, 64, 128] out_shape:[<tf.Tensor 'gen_A2B_1/strided_slice:0' shape=() dtype=int32>, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_A2B/u32: shape:[3, 3, 32, 64] out_shape:[<tf.Tensor 'gen_A2B_1/strided_slice_1:0' shape=() dtype=int32>, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh
#   [TL] InputLayer  gen_B2A/in: (?, ?, ?, 3)
#   [TL] Conv2dLayer gen_B2A/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/0: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/1: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/2: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/3: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/4: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/5: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/6: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/7: size:(?, ?, ?, 128) fn:add
#   [TL] Conv2dLayer gen_B2A/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A/b_residual_add/8: size:(?, ?, ?, 128) fn:add
#   [TL] DeConv2dLayer gen_B2A/u64: shape:[3, 3, 64, 128] out_shape:[<tf.Tensor 'gen_B2A_1/strided_slice:0' shape=() dtype=int32>, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_B2A/u32: shape:[3, 3, 32, 64] out_shape:[<tf.Tensor 'gen_B2A_1/strided_slice_1:0' shape=() dtype=int32>, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh
#   [TL] InputLayer  dis_A/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_A/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InputLayer  dis_B/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_B/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InputLayer  dis_A/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_A/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InputLayer  dis_B/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_B/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InputLayer  dis_A/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_A/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_A/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_A/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InputLayer  dis_B/d/in: (1, 70, 70, 3)
#   [TL] Conv2dLayer dis_B/d/h0/conv2d: shape:[4, 4, 3, 64] strides:[1, 2, 2, 1] pad:SAME act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h1/conv2d: shape:[4, 4, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h1/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h2/conv2d: shape:[4, 4, 128, 256] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h2/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h3/conv2d: shape:[4, 4, 256, 512] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer dis_B/d/h3/instance_norm: epsilon:0.000010 act:<lambda>
#   [TL] Conv2dLayer dis_B/d/h4/conv2d: shape:[4, 4, 512, 1] strides:[1, 1, 1, 1] pad:SAME act:identity

# %%
## test inference
# gen_B_test, gen_B_test_logits = cyclegan_generator_resnet(real_A, 9, is_train=False, reuse=True, name='gen_A2B')
# gen_A_test, gen_A_test_logits = cyclegan_generator_resnet(real_B, 9, is_train=False, reuse=True, name='gen_B2A')

# %%
## calculate cycle loss
cyc_loss = tf.reduce_mean(tf.abs(cyc_A_out - real_A)) + tf.reduce_mean(tf.abs(cyc_B_out - real_B))

## calculate adversial loss
g_loss_A2B = tf.reduce_mean(tf.squared_difference(d_fake_B_logits, tf.ones_like(d_fake_B_logits)), name='g_loss_b')
g_loss_B2A = tf.reduce_mean(tf.squared_difference(d_fake_A_logits, tf.ones_like(d_fake_A_logits)),name='g_loss_a')        # g_loss_B2A = tf.reduce_mean(tf.reduce_mean(tf.squared_difference(d_fake_A, tf.ones_like(d_fake_A)), [1, 2, 3]), name='g_loss_a')

## calculate totalloss of generator
g_a2b_loss = lamda * cyc_loss + g_loss_A2B  # forward
g_b2a_loss = lamda * cyc_loss + g_loss_B2A  # backward

## calculate discriminator loss
d_a_loss = (tf.reduce_mean(tf.squared_difference(d_real_A_logits, tf.ones_like(d_real_A_logits))) 
                                                 + tf.reduce_mean(tf.square(d_fake_A_logits))) / 2.0
d_b_loss = (tf.reduce_mean(tf.squared_difference(d_real_B_logits, tf.ones_like(d_real_B_logits))) 
                                                 + tf.reduce_mean(tf.square(d_fake_B_logits))) / 2.0

# %%
# t_vars = tf.trainable_variables()
g_A2B_vars = tl.layers.get_variables_with_name('gen_A2B', True, True)
g_B2A_vars = tl.layers.get_variables_with_name('gen_B2A', True, True)
d_A_vars = tl.layers.get_variables_with_name('dis_A', True, True)
d_B_vars = tl.layers.get_variables_with_name('dis_B', True, True)
# Out:
#   [*] geting variables with gen_A2B
#   got   0: gen_A2B/c7s1-32/W_conv2d:0   (7, 7, 3, 32)
#   got   1: gen_A2B/c7s1-32/b_conv2d:0   (32,)
#   got   2: gen_A2B/ins1/scale:0   (32,)
#   got   3: gen_A2B/ins1/offset:0   (32,)
#   got   4: gen_A2B/d64/W_conv2d:0   (3, 3, 32, 64)
#   got   5: gen_A2B/d64/b_conv2d:0   (64,)
#   got   6: gen_A2B/ins2/scale:0   (64,)
#   got   7: gen_A2B/ins2/offset:0   (64,)
#   got   8: gen_A2B/d128/W_conv2d:0   (3, 3, 64, 128)
#   got   9: gen_A2B/d128/b_conv2d:0   (128,)
#   got  10: gen_A2B/ins3/scale:0   (128,)
#   got  11: gen_A2B/ins3/offset:0   (128,)
#   got  12: gen_A2B/res/c1/0/W_conv2d:0   (3, 3, 128, 128)
#   got  13: gen_A2B/res/c1/0/b_conv2d:0   (128,)
#   got  14: gen_A2B/res/ins/0/scale:0   (128,)
#   got  15: gen_A2B/res/ins/0/offset:0   (128,)
#   got  16: gen_A2B/res/c2/0/W_conv2d:0   (3, 3, 128, 128)
#   got  17: gen_A2B/res/c2/0/b_conv2d:0   (128,)
#   got  18: gen_A2B/res/ins2/0/scale:0   (128,)
#   got  19: gen_A2B/res/ins2/0/offset:0   (128,)
#   got  20: gen_A2B/res/c1/1/W_conv2d:0   (3, 3, 128, 128)
#   got  21: gen_A2B/res/c1/1/b_conv2d:0   (128,)
#   got  22: gen_A2B/res/ins/1/scale:0   (128,)
#   got  23: gen_A2B/res/ins/1/offset:0   (128,)
#   got  24: gen_A2B/res/c2/1/W_conv2d:0   (3, 3, 128, 128)
#   got  25: gen_A2B/res/c2/1/b_conv2d:0   (128,)
#   got  26: gen_A2B/res/ins2/1/scale:0   (128,)
#   got  27: gen_A2B/res/ins2/1/offset:0   (128,)
#   got  28: gen_A2B/res/c1/2/W_conv2d:0   (3, 3, 128, 128)
#   got  29: gen_A2B/res/c1/2/b_conv2d:0   (128,)
#   got  30: gen_A2B/res/ins/2/scale:0   (128,)
#   got  31: gen_A2B/res/ins/2/offset:0   (128,)
#   got  32: gen_A2B/res/c2/2/W_conv2d:0   (3, 3, 128, 128)
#   got  33: gen_A2B/res/c2/2/b_conv2d:0   (128,)
#   got  34: gen_A2B/res/ins2/2/scale:0   (128,)
#   got  35: gen_A2B/res/ins2/2/offset:0   (128,)
#   got  36: gen_A2B/res/c1/3/W_conv2d:0   (3, 3, 128, 128)
#   got  37: gen_A2B/res/c1/3/b_conv2d:0   (128,)
#   got  38: gen_A2B/res/ins/3/scale:0   (128,)
#   got  39: gen_A2B/res/ins/3/offset:0   (128,)
#   got  40: gen_A2B/res/c2/3/W_conv2d:0   (3, 3, 128, 128)
#   got  41: gen_A2B/res/c2/3/b_conv2d:0   (128,)
#   got  42: gen_A2B/res/ins2/3/scale:0   (128,)
#   got  43: gen_A2B/res/ins2/3/offset:0   (128,)
#   got  44: gen_A2B/res/c1/4/W_conv2d:0   (3, 3, 128, 128)
#   got  45: gen_A2B/res/c1/4/b_conv2d:0   (128,)
#   got  46: gen_A2B/res/ins/4/scale:0   (128,)
#   got  47: gen_A2B/res/ins/4/offset:0   (128,)
#   got  48: gen_A2B/res/c2/4/W_conv2d:0   (3, 3, 128, 128)
#   got  49: gen_A2B/res/c2/4/b_conv2d:0   (128,)
#   got  50: gen_A2B/res/ins2/4/scale:0   (128,)
#   got  51: gen_A2B/res/ins2/4/offset:0   (128,)
#   got  52: gen_A2B/res/c1/5/W_conv2d:0   (3, 3, 128, 128)
#   got  53: gen_A2B/res/c1/5/b_conv2d:0   (128,)
#   got  54: gen_A2B/res/ins/5/scale:0   (128,)
#   got  55: gen_A2B/res/ins/5/offset:0   (128,)
#   got  56: gen_A2B/res/c2/5/W_conv2d:0   (3, 3, 128, 128)
#   got  57: gen_A2B/res/c2/5/b_conv2d:0   (128,)
#   got  58: gen_A2B/res/ins2/5/scale:0   (128,)
#   got  59: gen_A2B/res/ins2/5/offset:0   (128,)
#   got  60: gen_A2B/res/c1/6/W_conv2d:0   (3, 3, 128, 128)
#   got  61: gen_A2B/res/c1/6/b_conv2d:0   (128,)
#   got  62: gen_A2B/res/ins/6/scale:0   (128,)
#   got  63: gen_A2B/res/ins/6/offset:0   (128,)
#   got  64: gen_A2B/res/c2/6/W_conv2d:0   (3, 3, 128, 128)
#   got  65: gen_A2B/res/c2/6/b_conv2d:0   (128,)
#   got  66: gen_A2B/res/ins2/6/scale:0   (128,)
#   got  67: gen_A2B/res/ins2/6/offset:0   (128,)
#   got  68: gen_A2B/res/c1/7/W_conv2d:0   (3, 3, 128, 128)
#   got  69: gen_A2B/res/c1/7/b_conv2d:0   (128,)
#   got  70: gen_A2B/res/ins/7/scale:0   (128,)
#   got  71: gen_A2B/res/ins/7/offset:0   (128,)
#   got  72: gen_A2B/res/c2/7/W_conv2d:0   (3, 3, 128, 128)
#   got  73: gen_A2B/res/c2/7/b_conv2d:0   (128,)
#   got  74: gen_A2B/res/ins2/7/scale:0   (128,)
#   got  75: gen_A2B/res/ins2/7/offset:0   (128,)
#   got  76: gen_A2B/res/c1/8/W_conv2d:0   (3, 3, 128, 128)
#   got  77: gen_A2B/res/c1/8/b_conv2d:0   (128,)
#   got  78: gen_A2B/res/ins/8/scale:0   (128,)
#   got  79: gen_A2B/res/ins/8/offset:0   (128,)
#   got  80: gen_A2B/res/c2/8/W_conv2d:0   (3, 3, 128, 128)
#   got  81: gen_A2B/res/c2/8/b_conv2d:0   (128,)
#   got  82: gen_A2B/res/ins2/8/scale:0   (128,)
#   got  83: gen_A2B/res/ins2/8/offset:0   (128,)
#   got  84: gen_A2B/u64/W_deconv2d:0   (3, 3, 64, 128)
#   got  85: gen_A2B/u64/b_deconv2d:0   (64,)
#   got  86: gen_A2B/inso1/scale:0   (64,)
#   got  87: gen_A2B/inso1/offset:0   (64,)
#   got  88: gen_A2B/u32/W_deconv2d:0   (3, 3, 32, 64)
#   got  89: gen_A2B/u32/b_deconv2d:0   (32,)
#   got  90: gen_A2B/inso2/scale:0   (32,)
#   got  91: gen_A2B/inso2/offset:0   (32,)
#   got  92: gen_A2B/c7s1-3/W_conv2d:0   (7, 7, 32, 3)
#   got  93: gen_A2B/c7s1-3/b_conv2d:0   (3,)
#   [*] geting variables with gen_B2A
#   got   0: gen_B2A/c7s1-32/W_conv2d:0   (7, 7, 3, 32)
#   got   1: gen_B2A/c7s1-32/b_conv2d:0   (32,)
#   got   2: gen_B2A/ins1/scale:0   (32,)
#   got   3: gen_B2A/ins1/offset:0   (32,)
#   got   4: gen_B2A/d64/W_conv2d:0   (3, 3, 32, 64)
#   got   5: gen_B2A/d64/b_conv2d:0   (64,)
#   got   6: gen_B2A/ins2/scale:0   (64,)
#   got   7: gen_B2A/ins2/offset:0   (64,)
#   got   8: gen_B2A/d128/W_conv2d:0   (3, 3, 64, 128)
#   got   9: gen_B2A/d128/b_conv2d:0   (128,)
#   got  10: gen_B2A/ins3/scale:0   (128,)
#   got  11: gen_B2A/ins3/offset:0   (128,)
#   got  12: gen_B2A/res/c1/0/W_conv2d:0   (3, 3, 128, 128)
#   got  13: gen_B2A/res/c1/0/b_conv2d:0   (128,)
#   got  14: gen_B2A/res/ins/0/scale:0   (128,)
#   got  15: gen_B2A/res/ins/0/offset:0   (128,)
#   got  16: gen_B2A/res/c2/0/W_conv2d:0   (3, 3, 128, 128)
#   got  17: gen_B2A/res/c2/0/b_conv2d:0   (128,)
#   got  18: gen_B2A/res/ins2/0/scale:0   (128,)
#   got  19: gen_B2A/res/ins2/0/offset:0   (128,)
#   got  20: gen_B2A/res/c1/1/W_conv2d:0   (3, 3, 128, 128)
#   got  21: gen_B2A/res/c1/1/b_conv2d:0   (128,)
#   got  22: gen_B2A/res/ins/1/scale:0   (128,)
#   got  23: gen_B2A/res/ins/1/offset:0   (128,)
#   got  24: gen_B2A/res/c2/1/W_conv2d:0   (3, 3, 128, 128)
#   got  25: gen_B2A/res/c2/1/b_conv2d:0   (128,)
#   got  26: gen_B2A/res/ins2/1/scale:0   (128,)
#   got  27: gen_B2A/res/ins2/1/offset:0   (128,)
#   got  28: gen_B2A/res/c1/2/W_conv2d:0   (3, 3, 128, 128)
#   got  29: gen_B2A/res/c1/2/b_conv2d:0   (128,)
#   got  30: gen_B2A/res/ins/2/scale:0   (128,)
#   got  31: gen_B2A/res/ins/2/offset:0   (128,)
#   got  32: gen_B2A/res/c2/2/W_conv2d:0   (3, 3, 128, 128)
#   got  33: gen_B2A/res/c2/2/b_conv2d:0   (128,)
#   got  34: gen_B2A/res/ins2/2/scale:0   (128,)
#   got  35: gen_B2A/res/ins2/2/offset:0   (128,)
#   got  36: gen_B2A/res/c1/3/W_conv2d:0   (3, 3, 128, 128)
#   got  37: gen_B2A/res/c1/3/b_conv2d:0   (128,)
#   got  38: gen_B2A/res/ins/3/scale:0   (128,)
#   got  39: gen_B2A/res/ins/3/offset:0   (128,)
#   got  40: gen_B2A/res/c2/3/W_conv2d:0   (3, 3, 128, 128)
#   got  41: gen_B2A/res/c2/3/b_conv2d:0   (128,)
#   got  42: gen_B2A/res/ins2/3/scale:0   (128,)
#   got  43: gen_B2A/res/ins2/3/offset:0   (128,)
#   got  44: gen_B2A/res/c1/4/W_conv2d:0   (3, 3, 128, 128)
#   got  45: gen_B2A/res/c1/4/b_conv2d:0   (128,)
#   got  46: gen_B2A/res/ins/4/scale:0   (128,)
#   got  47: gen_B2A/res/ins/4/offset:0   (128,)
#   got  48: gen_B2A/res/c2/4/W_conv2d:0   (3, 3, 128, 128)
#   got  49: gen_B2A/res/c2/4/b_conv2d:0   (128,)
#   got  50: gen_B2A/res/ins2/4/scale:0   (128,)
#   got  51: gen_B2A/res/ins2/4/offset:0   (128,)
#   got  52: gen_B2A/res/c1/5/W_conv2d:0   (3, 3, 128, 128)
#   got  53: gen_B2A/res/c1/5/b_conv2d:0   (128,)
#   got  54: gen_B2A/res/ins/5/scale:0   (128,)
#   got  55: gen_B2A/res/ins/5/offset:0   (128,)
#   got  56: gen_B2A/res/c2/5/W_conv2d:0   (3, 3, 128, 128)
#   got  57: gen_B2A/res/c2/5/b_conv2d:0   (128,)
#   got  58: gen_B2A/res/ins2/5/scale:0   (128,)
#   got  59: gen_B2A/res/ins2/5/offset:0   (128,)
#   got  60: gen_B2A/res/c1/6/W_conv2d:0   (3, 3, 128, 128)
#   got  61: gen_B2A/res/c1/6/b_conv2d:0   (128,)
#   got  62: gen_B2A/res/ins/6/scale:0   (128,)
#   got  63: gen_B2A/res/ins/6/offset:0   (128,)
#   got  64: gen_B2A/res/c2/6/W_conv2d:0   (3, 3, 128, 128)
#   got  65: gen_B2A/res/c2/6/b_conv2d:0   (128,)
#   got  66: gen_B2A/res/ins2/6/scale:0   (128,)
#   got  67: gen_B2A/res/ins2/6/offset:0   (128,)
#   got  68: gen_B2A/res/c1/7/W_conv2d:0   (3, 3, 128, 128)
#   got  69: gen_B2A/res/c1/7/b_conv2d:0   (128,)
#   got  70: gen_B2A/res/ins/7/scale:0   (128,)
#   got  71: gen_B2A/res/ins/7/offset:0   (128,)
#   got  72: gen_B2A/res/c2/7/W_conv2d:0   (3, 3, 128, 128)
#   got  73: gen_B2A/res/c2/7/b_conv2d:0   (128,)
#   got  74: gen_B2A/res/ins2/7/scale:0   (128,)
#   got  75: gen_B2A/res/ins2/7/offset:0   (128,)
#   got  76: gen_B2A/res/c1/8/W_conv2d:0   (3, 3, 128, 128)
#   got  77: gen_B2A/res/c1/8/b_conv2d:0   (128,)
#   got  78: gen_B2A/res/ins/8/scale:0   (128,)
#   got  79: gen_B2A/res/ins/8/offset:0   (128,)
#   got  80: gen_B2A/res/c2/8/W_conv2d:0   (3, 3, 128, 128)
#   got  81: gen_B2A/res/c2/8/b_conv2d:0   (128,)
#   got  82: gen_B2A/res/ins2/8/scale:0   (128,)
#   got  83: gen_B2A/res/ins2/8/offset:0   (128,)
#   got  84: gen_B2A/u64/W_deconv2d:0   (3, 3, 64, 128)
#   got  85: gen_B2A/u64/b_deconv2d:0   (64,)
#   got  86: gen_B2A/inso1/scale:0   (64,)
#   got  87: gen_B2A/inso1/offset:0   (64,)
#   got  88: gen_B2A/u32/W_deconv2d:0   (3, 3, 32, 64)
#   got  89: gen_B2A/u32/b_deconv2d:0   (32,)
#   got  90: gen_B2A/inso2/scale:0   (32,)
#   got  91: gen_B2A/inso2/offset:0   (32,)
#   got  92: gen_B2A/c7s1-3/W_conv2d:0   (7, 7, 32, 3)
#   got  93: gen_B2A/c7s1-3/b_conv2d:0   (3,)
#   [*] geting variables with dis_A
#   got   0: dis_A/d/h0/conv2d/W_conv2d:0   (4, 4, 3, 64)
#   got   1: dis_A/d/h0/conv2d/b_conv2d:0   (64,)
#   got   2: dis_A/d/h1/conv2d/W_conv2d:0   (4, 4, 64, 128)
#   got   3: dis_A/d/h1/conv2d/b_conv2d:0   (128,)
#   got   4: dis_A/d/h1/instance_norm/scale:0   (128,)
#   got   5: dis_A/d/h1/instance_norm/offset:0   (128,)
#   got   6: dis_A/d/h2/conv2d/W_conv2d:0   (4, 4, 128, 256)
#   got   7: dis_A/d/h2/conv2d/b_conv2d:0   (256,)
#   got   8: dis_A/d/h2/instance_norm/scale:0   (256,)
#   got   9: dis_A/d/h2/instance_norm/offset:0   (256,)
#   got  10: dis_A/d/h3/conv2d/W_conv2d:0   (4, 4, 256, 512)
#   got  11: dis_A/d/h3/conv2d/b_conv2d:0   (512,)
#   got  12: dis_A/d/h3/instance_norm/scale:0   (512,)
#   got  13: dis_A/d/h3/instance_norm/offset:0   (512,)
#   got  14: dis_A/d/h4/conv2d/W_conv2d:0   (4, 4, 512, 1)
#   got  15: dis_A/d/h4/conv2d/b_conv2d:0   (1,)
#   [*] geting variables with dis_B
#   got   0: dis_B/d/h0/conv2d/W_conv2d:0   (4, 4, 3, 64)
#   got   1: dis_B/d/h0/conv2d/b_conv2d:0   (64,)
#   got   2: dis_B/d/h1/conv2d/W_conv2d:0   (4, 4, 64, 128)
#   got   3: dis_B/d/h1/conv2d/b_conv2d:0   (128,)
#   got   4: dis_B/d/h1/instance_norm/scale:0   (128,)
#   got   5: dis_B/d/h1/instance_norm/offset:0   (128,)
#   got   6: dis_B/d/h2/conv2d/W_conv2d:0   (4, 4, 128, 256)
#   got   7: dis_B/d/h2/conv2d/b_conv2d:0   (256,)
#   got   8: dis_B/d/h2/instance_norm/scale:0   (256,)
#   got   9: dis_B/d/h2/instance_norm/offset:0   (256,)
#   got  10: dis_B/d/h3/conv2d/W_conv2d:0   (4, 4, 256, 512)
#   got  11: dis_B/d/h3/conv2d/b_conv2d:0   (512,)
#   got  12: dis_B/d/h3/instance_norm/scale:0   (512,)
#   got  13: dis_B/d/h3/instance_norm/offset:0   (512,)
#   got  14: dis_B/d/h4/conv2d/W_conv2d:0   (4, 4, 512, 1)
#   got  15: dis_B/d/h4/conv2d/b_conv2d:0   (1,)

# %%
# with tf.device('/gpu:0'):
with tf.variable_scope('learning_rate'):
    lr_v = tf.Variable(learning_rate, trainable=False)
    
g_a2b_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(g_a2b_loss, var_list=g_A2B_vars)
g_b2a_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(g_b2a_loss, var_list=g_B2A_vars)
d_a_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(d_a_loss, var_list=d_A_vars)
d_b_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(d_b_loss, var_list=d_B_vars)

# %%
## init params
tl.layers.initialize_global_variables(sess)

net_g_A2B_name = os.path.join(checkpoint_dir, '{}_net_g_A2B.npz'.format(dataset_dir))
net_g_B2A_name = os.path.join(checkpoint_dir, '{}_net_g_B2A.npz'.format(dataset_dir))
net_d_A_name = os.path.join(checkpoint_dir, '{}_net_d_A.npz'.format(dataset_dir))
net_d_B_name = os.path.join(checkpoint_dir, '{}_net_d_B.npz'.format(dataset_dir))

tl.files.load_and_assign_npz(sess=sess, name=net_g_A2B_name, network=gen_B)
tl.files.load_and_assign_npz(sess=sess, name=net_g_B2A_name, network=gen_A)
tl.files.load_and_assign_npz(sess=sess, name=net_d_A_name, network=d_fake_A)
tl.files.load_and_assign_npz(sess=sess, name=net_d_B_name, network=d_fake_B)
# Out:
# [!] Load checkpoint\sunflower2daisy_net_g_A2B.npz failed!
# [!] Load checkpoint\sunflower2daisy_net_g_B2A.npz failed!
# [!] Load checkpoint\sunflower2daisy_net_d_A.npz failed!
# [!] Load checkpoint\sunflower2daisy_net_d_B.npz failed!
# False

# %%
    ##========================= TRAIN MODELS ================================##
    iter_counter = 1
    start_time = time.time()

    dataA, dataB, im_test_A, im_test_B = tl.files.load_cyclegan_dataset(filename=dataset_dir, path='datasets')

    sample_A = np.asarray(dataA[0: 16])
    sample_B = np.asarray(dataB[0: 16])
    sample_A = tl.prepro.threading_data(sample_A, fn=rescale)
    sample_B = tl.prepro.threading_data(sample_B, fn=rescale)

    tl.vis.save_images(sample_A, [4, 4], './{}/sample_A.jpg'.format(sample_dir))
    tl.vis.save_images(sample_B, [4, 4], './{}/sample_B.jpg'.format(sample_dir))

    shuffle(dataA)
    shuffle(dataB)

    for epoch in range(epoch):
        ## change learning rate
        if epoch >= 100:
            new_lr = learning_rate - learning_rate * (epoch - 100) / 100
            sess.run(tf.assign(lr_v, new_lr))
            print("New learning rate %f" % new_lr)

        batch_idxs = min(min(len(dataA), len(dataB)), train_size) // batch_size
        for idx in range(0, batch_idxs):
            batch_imgA = tl.prepro.threading_data(dataA[idx * batch_size:(idx + 1) * batch_size], fn=prepro)
            batch_imgB = tl.prepro.threading_data(dataB[idx * batch_size:(idx + 1) * batch_size], fn=prepro)

            gen_A_temp_out, gen_B_temp_out = sess.run([gen_A_out, gen_B_out],
                                feed_dict={real_A: batch_imgA, real_B: batch_imgB})

            ## update forward network
            _, errGA2B = sess.run([g_a2b_optim, g_a2b_loss],
                                feed_dict={real_A: batch_imgA, real_B: batch_imgB})
            ## update DB network
            _, errDB = sess.run([d_b_optim, d_b_loss],
                                feed_dict={real_A: batch_imgA, real_B: batch_imgB, fake_B_pool: gen_B_temp_out})
            ## update (backword) network
            _, errGB2A = sess.run([g_b2a_optim, g_b2a_loss],
                                feed_dict={real_A: batch_imgA, real_B: batch_imgB})
            ## update DA network
            _, errDA = sess.run([d_a_optim, d_a_loss],
                                feed_dict={real_A: batch_imgA, real_B: batch_imgB, fake_A_pool: gen_A_temp_out})

            print("Epoch: [%2d/%2d] [%4d/%4d] time: %4.4fs, d_a_loss: %.8f, d_b_loss: %.8f, g_a2b_loss: %.8f, g_b2a_loss: %.8f" \
                % (epoch, epoch, idx, batch_idxs, time.time() - start_time, errDA, errDB, errGA2B, errGB2A))

            iter_counter += 1
            # num_fake += 1

            if np.mod(iter_counter, 500) == 0:
                oA, oB = sess.run([gen_A_out, gen_B_out],
                                feed_dict={real_A: sample_A, real_B: sample_B})
                tl.vis.save_images(oA, [4, 4],
                                   './{}/B2A_{:02d}_{:04d}.jpg'.format(sample_dir, epoch, idx))
                print("save image gen_A, Epoch: %2d idx:%4d" % (epoch, idx))
                tl.vis.save_images(oB, [4, 4],
                                   './{}/A2B_{:02d}_{:04d}.jpg'.format(sample_dir, epoch, idx))
                print("save image gen_B, Epoch: %2d idx:%4d" % (epoch, idx))

        if (epoch != 0) and (epoch % 10) == 0:
            tl.files.save_npz(gen_B.all_params, name=net_g_A2B_name, sess=sess)
            tl.files.save_npz(gen_A.all_params, name=net_g_B2A_name, sess=sess)
            tl.files.save_npz(d_fake_A.all_params, name=net_d_A_name, sess=sess)
            tl.files.save_npz(d_fake_B.all_params, name=net_d_B_name, sess=sess)
            print("[*] Save checkpoints SUCCESS!")
# Out:
# Epoch: [ 0/ 0] [   0/  50] time: 44.5225s, d_a_loss: 2.61251187, d_b_loss: 1.25806665, g_a2b_loss: 14.26827049, g_b2a_loss: 16.44950867
# Epoch: [ 0/ 0] [   1/  50] time: 85.8782s, d_a_loss: 1.34255135, d_b_loss: 1.67882121, g_a2b_loss: 14.75351429, g_b2a_loss: 15.90030956
# Epoch: [ 0/ 0] [   2/  50] time: 127.2182s, d_a_loss: 1.68632078, d_b_loss: 2.50046754, g_a2b_loss: 14.38656425, g_b2a_loss: 14.48825836
# Epoch: [ 0/ 0] [   3/  50] time: 168.4335s, d_a_loss: 1.43790352, d_b_loss: 1.85401762, g_a2b_loss: 14.82560349, g_b2a_loss: 14.26157379
# Epoch: [ 0/ 0] [   4/  50] time: 209.7112s, d_a_loss: 1.46684086, d_b_loss: 1.15182543, g_a2b_loss: 12.53977871, g_b2a_loss: 12.57348156
# Epoch: [ 0/ 0] [   5/  50] time: 251.0824s, d_a_loss: 1.38981342, d_b_loss: 1.70688689, g_a2b_loss: 12.99608040, g_b2a_loss: 12.11594486
# Epoch: [ 0/ 0] [   6/  50] time: 292.2821s, d_a_loss: 1.52420950, d_b_loss: 1.96311903, g_a2b_loss: 13.39662361, g_b2a_loss: 13.17093754
# Epoch: [ 0/ 0] [   7/  50] time: 333.4506s, d_a_loss: 1.56518960, d_b_loss: 1.89697003, g_a2b_loss: 13.45108891, g_b2a_loss: 12.92808628
# Epoch: [ 0/ 0] [   8/  50] time: 374.8999s, d_a_loss: 0.92666143, d_b_loss: 1.11626148, g_a2b_loss: 13.40762424, g_b2a_loss: 13.43373871
# Epoch: [ 0/ 0] [   9/  50] time: 416.0059s, d_a_loss: 1.12440586, d_b_loss: 1.60356641, g_a2b_loss: 12.41561604, g_b2a_loss: 11.58584499
# Epoch: [ 0/ 0] [  10/  50] time: 457.5800s, d_a_loss: 1.05217195, d_b_loss: 1.22601700, g_a2b_loss: 10.13725090, g_b2a_loss: 10.05379200
# Epoch: [ 0/ 0] [  11/  50] time: 499.0449s, d_a_loss: 1.08449244, d_b_loss: 0.90700060, g_a2b_loss: 13.98370743, g_b2a_loss: 13.20151520
# Epoch: [ 0/ 0] [  12/  50] time: 540.6501s, d_a_loss: 1.59801984, d_b_loss: 1.76583505, g_a2b_loss: 11.20382118, g_b2a_loss: 10.62806892
# Epoch: [ 0/ 0] [  13/  50] time: 581.8186s, d_a_loss: 1.74482131, d_b_loss: 1.03486085, g_a2b_loss: 13.09496403, g_b2a_loss: 11.96247101
# Epoch: [ 0/ 0] [  14/  50] time: 623.2367s, d_a_loss: 0.92779040, d_b_loss: 1.32886255, g_a2b_loss: 13.88422966, g_b2a_loss: 12.92755222
# Epoch: [ 0/ 0] [  15/  50] time: 664.4208s, d_a_loss: 1.10537446, d_b_loss: 1.27182913, g_a2b_loss: 9.70168304, g_b2a_loss: 9.86293316
# Epoch: [ 0/ 0] [  16/  50] time: 705.6204s, d_a_loss: 0.94114792, d_b_loss: 1.00004959, g_a2b_loss: 12.81294537, g_b2a_loss: 12.78806210
# Epoch: [ 0/ 0] [  17/  50] time: 746.9449s, d_a_loss: 0.87901402, d_b_loss: 1.60303140, g_a2b_loss: 11.57757854, g_b2a_loss: 11.72208023
# Epoch: [ 0/ 0] [  18/  50] time: 788.0666s, d_a_loss: 1.70518005, d_b_loss: 1.19775319, g_a2b_loss: 11.42825699, g_b2a_loss: 10.18104649
# Epoch: [ 0/ 0] [  19/  50] time: 829.2351s, d_a_loss: 0.99792820, d_b_loss: 1.22014177, g_a2b_loss: 10.26104355, g_b2a_loss: 10.99410725
# Epoch: [ 0/ 0] [  20/  50] time: 870.4659s, d_a_loss: 1.26882470, d_b_loss: 1.37529874, g_a2b_loss: 11.74880409, g_b2a_loss: 12.08693409
# Epoch: [ 0/ 0] [  21/  50] time: 911.6656s, d_a_loss: 0.89139414, d_b_loss: 1.42393279, g_a2b_loss: 9.97523308, g_b2a_loss: 9.77722645
# Epoch: [ 0/ 0] [  22/  50] time: 952.8185s, d_a_loss: 2.04611564, d_b_loss: 0.91336894, g_a2b_loss: 10.92266369, g_b2a_loss: 10.98608780
# Epoch: [ 0/ 0] [  23/  50] time: 994.1429s, d_a_loss: 0.82178998, d_b_loss: 1.20428944, g_a2b_loss: 13.26338768, g_b2a_loss: 13.52642441
# Epoch: [ 0/ 0] [  24/  50] time: 1035.3270s, d_a_loss: 0.96899068, d_b_loss: 1.43992043, g_a2b_loss: 12.24568367, g_b2a_loss: 12.90171623
# Epoch: [ 0/ 0] [  25/  50] time: 1076.9167s, d_a_loss: 1.00908411, d_b_loss: 1.08780932, g_a2b_loss: 10.12740040, g_b2a_loss: 10.49721527
# Epoch: [ 0/ 0] [  26/  50] time: 1118.1944s, d_a_loss: 0.62296724, d_b_loss: 1.08030629, g_a2b_loss: 10.65633774, g_b2a_loss: 10.26999474
# Epoch: [ 0/ 0] [  27/  50] time: 1159.7840s, d_a_loss: 0.95604527, d_b_loss: 1.02181172, g_a2b_loss: 10.24934864, g_b2a_loss: 10.08916378
# Epoch: [ 0/ 0] [  28/  50] time: 1201.0305s, d_a_loss: 0.98753685, d_b_loss: 0.94385254, g_a2b_loss: 11.43480587, g_b2a_loss: 11.62979889
# Epoch: [ 0/ 0] [  29/  50] time: 1242.4018s, d_a_loss: 0.98612261, d_b_loss: 0.75211424, g_a2b_loss: 9.39492035, g_b2a_loss: 9.52643108
# Epoch: [ 0/ 0] [  30/  50] time: 1283.5547s, d_a_loss: 1.05581808, d_b_loss: 1.31899071, g_a2b_loss: 10.20334530, g_b2a_loss: 9.86082268
# Epoch: [ 0/ 0] [  31/  50] time: 1324.7075s, d_a_loss: 0.70320988, d_b_loss: 1.70999575, g_a2b_loss: 10.42281055, g_b2a_loss: 9.55833340
# Epoch: [ 0/ 0] [  32/  50] time: 1366.0476s, d_a_loss: 2.06154633, d_b_loss: 1.14809263, g_a2b_loss: 8.47063923, g_b2a_loss: 8.21319294
# Epoch: [ 0/ 0] [  33/  50] time: 1407.1849s, d_a_loss: 0.81508458, d_b_loss: 1.33667636, g_a2b_loss: 9.72240925, g_b2a_loss: 9.62926960
# Epoch: [ 0/ 0] [  34/  50] time: 1448.4313s, d_a_loss: 1.54766834, d_b_loss: 1.18352544, g_a2b_loss: 9.73539925, g_b2a_loss: 9.61448383
# Epoch: [ 0/ 0] [  35/  50] time: 1489.5842s, d_a_loss: 2.24366283, d_b_loss: 1.54363585, g_a2b_loss: 7.66841650, g_b2a_loss: 7.36553240
# Epoch: [ 0/ 0] [  36/  50] time: 1530.8775s, d_a_loss: 1.46115720, d_b_loss: 1.00268710, g_a2b_loss: 9.21360779, g_b2a_loss: 9.48720360
# Epoch: [ 0/ 0] [  37/  50] time: 1572.1396s, d_a_loss: 0.81034482, d_b_loss: 1.19528675, g_a2b_loss: 10.09711170, g_b2a_loss: 9.55434227
# Epoch: [ 0/ 0] [  38/  50] time: 1613.3236s, d_a_loss: 1.26872516, d_b_loss: 0.89849138, g_a2b_loss: 7.76363945, g_b2a_loss: 7.29911470
# Epoch: [ 0/ 0] [  39/  50] time: 1654.4765s, d_a_loss: 1.46000803, d_b_loss: 1.51087999, g_a2b_loss: 9.50299454, g_b2a_loss: 9.98523235
# Epoch: [ 0/ 0] [  40/  50] time: 1695.8946s, d_a_loss: 1.42302024, d_b_loss: 0.73847669, g_a2b_loss: 9.00856113, g_b2a_loss: 8.22326279
# Epoch: [ 0/ 0] [  41/  50] time: 1737.0631s, d_a_loss: 1.16310120, d_b_loss: 1.79159689, g_a2b_loss: 10.49831867, g_b2a_loss: 9.38096809
# Epoch: [ 0/ 0] [  42/  50] time: 1778.3563s, d_a_loss: 0.85120070, d_b_loss: 1.13589633, g_a2b_loss: 9.32122898, g_b2a_loss: 9.71624470
# Epoch: [ 0/ 0] [  43/  50] time: 1819.6028s, d_a_loss: 2.46294475, d_b_loss: 1.90307188, g_a2b_loss: 9.97655296, g_b2a_loss: 9.57810974
# Epoch: [ 0/ 0] [  44/  50] time: 1860.8337s, d_a_loss: 0.79945737, d_b_loss: 0.54484403, g_a2b_loss: 9.80094147, g_b2a_loss: 8.13320923
# Epoch: [ 0/ 0] [  45/  50] time: 1902.0177s, d_a_loss: 3.63721132, d_b_loss: 1.58640337, g_a2b_loss: 12.19846821, g_b2a_loss: 12.15938473
# Epoch: [ 0/ 0] [  46/  50] time: 1943.3734s, d_a_loss: 0.90036547, d_b_loss: 2.54079795, g_a2b_loss: 8.14635086, g_b2a_loss: 7.61160517
# Epoch: [ 0/ 0] [  47/  50] time: 1984.6199s, d_a_loss: 1.75092614, d_b_loss: 1.04237175, g_a2b_loss: 9.02140808, g_b2a_loss: 9.10081387
# Epoch: [ 0/ 0] [  48/  50] time: 2025.7416s, d_a_loss: 1.55821848, d_b_loss: 1.06976986, g_a2b_loss: 6.90734434, g_b2a_loss: 7.17729616
# Epoch: [ 0/ 0] [  49/  50] time: 2067.0660s, d_a_loss: 1.55472076, d_b_loss: 1.32791948, g_a2b_loss: 9.41666603, g_b2a_loss: 9.77147102

# %% [markdown]
# ## Test cyclegan

# %%
def pro(x):
    x = x / (255. / 2.)
    x = x - 1.
    return x

# %%
test_A = tf.placeholder(tf.float32, [batch_size, image_size, image_size, c_dim], name='test_x')
test_B = tf.placeholder(tf.float32, [batch_size, image_size, image_size, c_dim], name='test_y')
test_gen_A2B, test_gen_A2B_logits = cyclegan_generator_resnet(test_A, 9, is_train=False, 
                                                              reuse=False, name='gen_A2B2')
test_gen_B2A, test_gen_B2A_logits = cyclegan_generator_resnet(test_B, 9, is_train=False, 
                                                              reuse=False, name='gen_B2A2')
    
out_var, in_var = (test_B, test_A) if direction == 'forward' else (test_A, test_B)
# Out:
#   [TL] InputLayer  gen_A2B2/in: (1, 256, 256, 3)
#   [TL] Conv2dLayer gen_A2B2/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/0: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/1: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/2: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/3: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/4: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/5: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/6: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/7: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_A2B2/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_A2B2/b_residual_add/8: size:(1, 64, 64, 128) fn:add
#   [TL] DeConv2dLayer gen_A2B2/u64: shape:[3, 3, 64, 128] out_shape:[1, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_A2B2/u32: shape:[3, 3, 32, 64] out_shape:[1, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_A2B2/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_A2B2/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh
#   [TL] InputLayer  gen_B2A2/in: (1, 256, 256, 3)
#   [TL] Conv2dLayer gen_B2A2/c7s1-32: shape:[7, 7, 3, 32] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/ins1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/d64: shape:[3, 3, 32, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/ins2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/d128: shape:[3, 3, 64, 128] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/ins3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c1/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/0: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/0: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/0: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/0: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/1: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/1: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/1: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/1: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/2: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/2: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/2: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/3: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/3: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/3: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/3: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/4: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/4: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/4: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/4: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/5: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/5: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/5: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/5: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/6: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/6: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/6: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/6: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/7: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/7: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/7: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/7: size:(1, 64, 64, 128) fn:add
#   [TL] Conv2dLayer gen_B2A2/res/c1/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins/8: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/res/c2/8: shape:[3, 3, 128, 128] strides:[1, 1, 1, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/res/ins2/8: epsilon:0.000010 act:identity
#   [TL] ElementwiseLayer gen_B2A2/b_residual_add/8: size:(1, 64, 64, 128) fn:add
#   [TL] DeConv2dLayer gen_B2A2/u64: shape:[3, 3, 64, 128] out_shape:[1, 128, 128, 64] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/inso1: epsilon:0.000010 act:relu
#   [TL] DeConv2dLayer gen_B2A2/u32: shape:[3, 3, 32, 64] out_shape:[1, 256, 256, 32] strides:[1, 2, 2, 1] pad:SAME act:identity
#   [TL] InstanceNormLayer gen_B2A2/inso2: epsilon:0.000010 act:relu
#   [TL] Conv2dLayer gen_B2A2/c7s1-3: shape:[7, 7, 32, 3] strides:[1, 1, 1, 1] pad:SAME act:tanh

# %%
sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True))
tl.layers.initialize_global_variables(sess)

# %%
net_g_A2B_name = os.path.join(checkpoint_dir, '{}_net_g_A2B.npz'.format(dataset_dir))
net_g_B2A_name = os.path.join(checkpoint_dir, '{}_net_g_B2A.npz'.format(dataset_dir))
tl.files.load_and_assign_npz(sess=sess, name=net_g_A2B_name, network=test_gen_A2B)
tl.files.load_and_assign_npz(sess=sess, name=net_g_B2A_name, network=test_gen_B2A)
# Out:
# [!] Load checkpoint\sunflower2daisy_net_g_A2B.npz failed!
# [!] Load checkpoint\sunflower2daisy_net_g_B2A.npz failed!
# False

# %%
dataA, dataB, im_test_A, im_test_B = tl.files.load_cyclegan_dataset(filename=dataset_dir, path='datasets')

if direction == 'forward':
    sample_files = im_test_A
    net_g_logits = test_gen_A2B_logits

elif direction == 'backward':
    sample_files = im_test_B
    net_g_logits = test_gen_B2A_logits
else:
    raise Exception('--direction must be forward or backward')

# %%
batch_idxs = (len(sample_files)) // batch_size
    
for idx in range(0, batch_idxs):
    sample_image = threading_data(sample_files[idx * batch_size:(idx + 1) * batch_size],fn=pro)
    fake_img = sess.run(net_g_logits, feed_dict={in_var: sample_image})
    tl.vis.save_images(fake_img, [ni, ni], './{}/A2B_{}_{:04d}.jpg'.format(test_dir, direction, idx))

# %% [markdown]
# ### Final Results:
#
# <img src="assets/result.png" style="width: 600px;"/>
#
# <img src="assets/result2.png" style="width: 600px;"/>
